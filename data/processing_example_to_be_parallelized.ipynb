# %% [markdown]
# Please use the current development version and report any bugs you encounter:
# `pip install git+https://github.com/DCMLab/wavescapes.git@corpus_structure`

# %%
import os, shutil, subprocess
import ms3
import ray

# %%
DATA_FOLDER = os.path.abspath('../mscz') # on the HPC: /scratch/data/musescore.com/
SAMPLE_FOLDER = os.path.abspath('./mscz')
CONVERSION_FOLDER = os.path.abspath('./mscx')
OUTPUT_PATHS = dict(
    events = os.path.abspath('./events'),
    notes = os.path.abspath('./notes'),
    measures = os.path.abspath('./measures'),
    labels = os.path.abspath('./labels'),
    metadata = os.path.abspath('./metadata'),
)

# %% [markdown]
# Creating a sample of 1000 zipped MuseScore 3 for development purposes:

# %% [raw]
# for i, entry in enumerate(os.scandir(DATA_FOLDER)):
#     if i == 1000:
#         break
#     if entry.name.endswith('.mscz'):
#         shutil.copy(entry.path, os.path.join(SAMPLE_FOLDER, entry.name))

# %% [markdown]
# Using the MuseScore 3 binary to convert the file format to the current version of MuseScore 3 (needs to be installed or available as AppImage). [MuseScore commandline options](https://musescore.org/en/handbook/3/command-line-options)
#
# ToDos:
#
# * parallelize the conversion (anyone interested in learning [ray](https://www.ray.io/)?)
# * avoid processing files more than once, making use of the fact that the file names correspond to IDs
# * add proper error handling, keeping track of a mapping ID -> `errors message` for files that cannot successfully be converted (checkout stdout and stderr arguments of [subprocess.run()](https://docs.python.org/3/library/subprocess.html#subprocess.run))

# %%
# indicate the path to your MuseScore 3 executable or try using the standard path:
musescore_cmd = "mscore-portable" #ms3.get_musescore('auto')
print(musescore_cmd)
# Out:
# mscore-portable

# %%
ray.init()
# Out:
# 2022-11-24 18:43:49,956	INFO worker.py:1528 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.8.8', ray_version='2.1.0', ray_commit='be49bde7ee4f6adb3f8710aee0665c27f9f0bb62', address_info={'node_ip_address': '192.168.1.169', 'raylet_ip_address': '192.168.1.169', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-11-24_18-43-47_617217_236945/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-11-24_18-43-47_617217_236945/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2022-11-24_18-43-47_617217_236945', 'metrics_export_port': 56309, 'gcs_address': '192.168.1.169:51023', 'address': '192.168.1.169:51023', 'dashboard_agent_listen_port': 52365, 'node_id': 'a0d51b4cb3a424a0b665e8c49f38b781bc6dc75e8d76427826cc44f2'})

# %%
@ray.remote
def process_chunk(start_idx, end_idx):
    for i, entry in enumerate(os.scandir(SAMPLE_FOLDER)):
        if i < start_idx:
            continue
        if i >= end_idx:
            break
        ID, file_extension = os.path.splitext(entry.name)
        converted_file_path = os.path.join(CONVERSION_FOLDER, ID + '.mscx')
        print(f"Converting {entry.path} to {converted_file_path}...", end=' ')
        
        result = subprocess.run([musescore_cmd,"--score-meta", "-o", converted_file_path, entry.path], capture_output=True, text=True)
        print(f"Exit code: {result.returncode}")
        print(f"Result: {result.stdout.strip()}") # the extraction of metadata as JSON does not work on Windows; please store the JSON to the metadata output folder
        print(f"Errors: {result.stderr.strip()}")

# %%
futures = [process_chunk.remote(i*100, i*100+100) for i in range (10)]
# Out:
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101555.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101555.mscx...
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102059.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102059.mscx...
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102715.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102715.mscx...
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101289.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101289.mscx...
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100753.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100753.mscx...
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1004766.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1004766.mscx...
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100462.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100462.mscx...
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1030126.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1030126.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"J.F.Burgmüller","duration":127,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":46,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73}],"poet":"","previousSource":"","subtitle":"","tempo":132,"tempoText":"<font face=\"Times New Roman\"/><b>Allegro</b>","textFramesData":{"composers":["J.F.Burgmüller"],"poets":[],"subtitles":[],"titles":["La chevaleresque"]},"timesig":"4/4","title":"La chevaleresque"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1017091.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1017091.mscx...
# (process_chunk pid=237241) Exit code: 0
# (process_chunk pid=237241) Result: {
# (process_chunk pid=237241) "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Erin Taylor Nicole"]},"timesig":"4/4","title":"Erin Taylor Nicole"}
# (process_chunk pid=237241) }
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020611.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020611.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"A. Borodin","duration":58,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":0,"lyrics":"Slava Kirillu! Slava Mefodiiu, slava! Prosvetiteliam nashim slava! Svetom istini nas ozarivshim. Prosvetiteliam vseh slavian. Slava! slava! Slava! \n\nSlava Kirillu! Slava Mefodiiu! Slava! Slava Kirillu! Slava Mefodiiu!","measures":17,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":70,"name":"","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":70,"tempoText":"<font face=\"Times New Roman\"/><b>Moderato</b>","textFramesData":{"composers":["A. Borodin"],"poets":[],"subtitles":[],"titles":["Slava Kirillu i Mefodiiu"]},"timesig":"4/4","title":"Slava Kirillu i Mefodiiu"}
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013431.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1013431.mscx...
# (process_chunk pid=237238) Exit code: 0
# (process_chunk pid=237238) Result: {
# (process_chunk pid=237238) "metadata": {"composer":"Arranged by : Eggi Ajisukma","duration":54,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-2,"lyrics":"","measures":21,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":5,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"Tuba","program":58},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"drum.timpani","isVisible":"true","lyricCount":0,"name":"Timpani","program":47},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.tubular-bells","isVisible":"true","lyricCount":0,"name":"Tubular Bells","program":14},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.tubular-bells","isVisible":"true","lyricCount":0,"name":"Tubular Bells","program":14},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.tubular-bells","isVisible":"true","lyricCount":0,"name":"Tubular Bells","program":14}],"poet":"","previousSource":"","subtitle":"","tempo":93,"tempoText":"<sym>metNoteQuarterUp</sym> = 93","textFramesData":{"composers":["Arranged by : Eggi Ajisukma"],"poets":[],"subtitles":[],"titles":["Do You Wanna Build A Snowman"]},"timesig":"4/4","title":"Do You Wanna Build A Snowman"}
# (process_chunk pid=237238) }
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/103516.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/103516.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"Brandon Liu and Braden Shimp","duration":37,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":11,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.glockenspiel.soprano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Tubular Glockenspiel","program":9},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Didgeritube","program":0}],"poet":"Columbus Academy\nDivison B: Team B-32 ","previousSource":"","subtitle":"","tempo":72,"tempoText":"<font face=\"Times New Roman\"/><b>Larghetto</b>","textFramesData":{"composers":["Brandon Liu and Braden Shimp"],"poets":["Columbus Academy\nDivison B: Team B-32 "],"subtitles":[],"titles":["Theme Movement #2 New World Symphony"]},"timesig":"4/4","title":"Theme Movement #2 New World Symphony"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1023996.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1023996.mscx...
# (process_chunk pid=237237) Exit code: 0
# (process_chunk pid=237237) Result: {
# (process_chunk pid=237237) "metadata": {"composer":"arr. Jameson Nizo","duration":78,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-3,"lyrics":"","measures":29,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":8,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Sax","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"Tenor Sax","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"Guitar","program":27},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.bass.acoustic","isVisible":"true","lyricCount":0,"name":"Bass","program":32},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"Drums","program":0}],"poet":"","previousSource":"https://musescore.com/score/1004766","subtitle":"","tempo":160,"tempoText":"<sym>metNoteQuarterUp</sym> = 160","textFramesData":{"composers":["arr. Jameson Nizo"],"poets":[],"subtitles":[],"titles":["キカイダ"]},"timesig":"4/4","title":"キカイダ"}
# (process_chunk pid=237237) }
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102454.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102454.mscx...
# (process_chunk pid=237235) Exit code: 0
# (process_chunk pid=237235) Result: {
# (process_chunk pid=237235) "metadata": {"composer":"","duration":94,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":2,"lyrics":"","measures":21,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello","program":42}],"poet":"arr. Jonathan St. Vincent","previousSource":"","subtitle":"Solo Cello Arrangement","tempo":80,"tempoText":"<font face=\"Times New Roman\"/><b>80 BPM</b>","textFramesData":{"composers":[],"poets":["arr. Jonathan St. Vincent"],"subtitles":["Solo Cello Arrangement"],"titles":["Cannon in D"]},"timesig":"4/4","title":"Cannon in D"}
# (process_chunk pid=237235) }
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1033281.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1033281.mscx...
# (process_chunk pid=237236) Exit code: 0
# (process_chunk pid=237236) Result: {
# (process_chunk pid=237236) "metadata": {"composer":"Metallica","duration":206,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":1,"lyrics":"","measures":140,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.nylon-string","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Chitarra","program":24}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["Metallica"],"poets":[],"subtitles":[],"titles":["Nothing Else Matters"]},"timesig":"6/8","title":"Nothing Else Matters"}
# (process_chunk pid=237236) }
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1026286.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1026286.mscx...
# (process_chunk pid=237239) Exit code: 1
# (process_chunk pid=237239) Result:
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) QZip: not a zip file!
# (process_chunk pid=237239) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013431.mscz:
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102897.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102897.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"","duration":72,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-2,"lyrics":"","measures":24,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.recorder","isVisible":"true","lyricCount":0,"name":"Blockflöte","program":74},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"B Tuba","program":58}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Muotataler Mazurka"]},"timesig":"3/4","title":"Muotataler Mazurka"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101624.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101624.mscx...
# (process_chunk pid=237238) Exit code: 0
# (process_chunk pid=237238) Result: {
# (process_chunk pid=237238) "metadata": {"composer":"Arranged by KHALIL STEWART","duration":174,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-2,"lyrics":"","measures":87,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Alto Saxophone","program":65}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["Arranged by KHALIL STEWART"],"poets":[],"subtitles":[],"titles":["Trouble/ As Long as You Love Me/ Wide Awake"]},"timesig":"4/4","title":"Trouble/ As Long as You Love Me/ Wide Awake"}
# (process_chunk pid=237238) }
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101155.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101155.mscx...
# (process_chunk pid=237235) Exit code: 0
# (process_chunk pid=237235) Result: {
# (process_chunk pid=237235) "metadata": {"composer":"Phill Collins","duration":288,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":74,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":3,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"Piano","program":0}],"poet":"","previousSource":"","subtitle":"En mi corazón \"Tarzan\"","tempo":80,"tempoText":"<sym>metNoteQuarterUp</sym> = 80","textFramesData":{"composers":["Phill Collins"],"poets":[],"subtitles":["En mi corazón \"Tarzan\""],"titles":["You´ll Be in My Heart"]},"timesig":"4/4","title":"You´ll Be in My Heart"}
# (process_chunk pid=237235) }
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) Trying to construct an instance of an invalid type, type id: 54112288
# (process_chunk pid=237235) Trying to construct an instance of an invalid type, type id: 54112288
# (process_chunk pid=237235) Trying to construct an instance of an invalid type, type id: 54170128
# (process_chunk pid=237235) Trying to construct an instance of an invalid type, type id: 54170128
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1030611.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1030611.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"Ton Lans","duration":105,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"true","keysig":-6,"lyrics":"Onze Vader in de Hemel, laat uw naam geheiligd worden, laat uw Koninkrijk kome en uw wil gedaan worden op aarde zoals in de hemel. Geef ons vandaag het brood dat wij nodig hebben. Vergeef ons onze schulden, zo als ook wij hebben vergeven wie ons iets schuldig was. En breng ons niet in beproeving, maar red ons uit de greep van het kwaad. Want aan U behoort het koningschap, de macht en de majesteit tot in eeuwigheid. Amen.","measures":35,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.vocals","isVisible":"true","lyricCount":113,"name":"S A","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.vocals","isVisible":"true","lyricCount":0,"name":"T B","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"Piano","program":0}],"poet":"","previousSource":"https://musescore.com/score/1017091","subtitle":"Tekst NBV","tempo":80,"tempoText":"<sym>metNoteQuarterUp</sym> = 80","textFramesData":{"composers":["Ton Lans"],"poets":[],"subtitles":["Tekst NBV"],"titles":["Onze Vader"]},"timesig":"2/2","title":"Onze Vader"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1006.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1006.mscx...
# (process_chunk pid=237241) Exit code: 0
# (process_chunk pid=237241) Result: {
# (process_chunk pid=237241) "metadata": {"composer":"Arr. Raven Simon","duration":79,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":48,"mscoreVersion":"2.0.0","pageFormat":{"height":279,"twosided":"false","width":216},"pages":7,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bass","isVisible":"true","lyricCount":0,"name":"Bass Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"Baritone Saxophone","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"Tuba","program":58},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.marimba","isVisible":"true","lyricCount":0,"name":"Marimba","program":12},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.vibraphone","isVisible":"true","lyricCount":0,"name":"Vibraphone","program":11},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.xylophone","isVisible":"true","lyricCount":0,"name":"Xylophone","program":13},{"harmonyC ...
# (process_chunk pid=237241) }
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1035766.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1035766.mscx...
# (process_chunk pid=237237) Exit code: 0
# (process_chunk pid=237237) Result: {
# (process_chunk pid=237237) "metadata": {"composer":"Wladimir Rébikow","duration":143,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":52,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":6,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73}],"poet":"","previousSource":"","subtitle":"5","tempo":72,"tempoText":"<font face=\"Times New Roman\"/><b>Adagio</b>","textFramesData":{"composers":["Wladimir Rébikow"],"poets":[],"subtitles":["5"],"titles":["Souvenir des temps passés"]},"timesig":"4/4","title":"Souvenir des temps passés"}
# (process_chunk pid=237237) }
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1025421.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1025421.mscx...
# (process_chunk pid=237236) Exit code: 0
# (process_chunk pid=237236) Result: {
# (process_chunk pid=237236) "metadata": {"composer":"","duration":242,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":89,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":7,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"長笛","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"長笛","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"長笛","program":73}],"poet":"","previousSource":"","subtitle":"Dance with 【めろちん】","tempo":120,"tempoText":"<sym>metNoteQuarterUp</sym> = 120","textFramesData":{"composers":[],"poets":[],"subtitles":["Dance with 【めろちん】"],"titles":["Happy Synthesizer (ハッピーシンセサイザ)"]},"timesig":"4/4","title":"Happy Synthesizer (ハッピーシンセサイザ)"}
# (process_chunk pid=237236) }
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1014026.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1014026.mscx...
# (process_chunk pid=237235) Exit code: 1
# (process_chunk pid=237235) Result:
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) QZip: not a zip file!
# (process_chunk pid=237235) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1030611.mscz:
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102139.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102139.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"","duration":32,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":0,"lyrics":"A csillagok, ha beszélni tudnának, A lányokról mindent kivallanának, A lányokról mindent kivallanának, Sok szép lányok szégyenbe maradnának.","measures":12,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":44,"name":"<font face=\"Times New Roman\"/>Felső szólam","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":72,"tempoText":"<font face=\"Times New Roman\"/><b>Maestoso</b>","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["A csillagok, ha beszélni tudnának\n(felső szólam)"]},"timesig":"5/8","title":"A csillagok, ha beszélni tudnának\n(felső szólam)"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102962.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102962.mscx...
# (process_chunk pid=237241) Exit code: 0
# (process_chunk pid=237241) Result: {
# (process_chunk pid=237241) "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["#9 Bass Cleff song #3"]},"timesig":"4/4","title":"#9 Bass Cleff song #3"}
# (process_chunk pid=237241) }
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1014811.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1014811.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"","duration":98,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":1,"lyrics":"Mi maestra/enseña que El Libro de Mormón de los lamanitas hace una relación. Mucho ha sus padres se/embarcaron de/ultra mar, y/el país por su fe a/heredar. En los muros una vez profetizó Samuel. Era lamanita y también un hombre fiel. Le lanzaron flechas, pero Dios lo protegió. Siempre en rectitud Él vivió.Cristo, luego de su muerte y resurrección, descendió y/ha cada niño dio Su bendición, y Su Evangelio a la gente enseñó. Hubo paz, la verdad se vivió.Vienen muchos otros que buscan libres ser, el país optó por recoger. Dice/El Libro de Mormón: En hermandad andad y/el país por la fe heredar. Y/el país por la fe heredar. \n\nMi maestra/enseña que El Libro de Mormón de los lamanitas hace una relación. Mucho ha sus padres se/embarcaron de/ultra mar, y/el país por su fe a/here dar. En los muros una vez profetizó Samuel. Era lamanita y también un hombre fiel. Le lanzaron flechas, pero Dios lo protegió. Siempre en rectitud Él vivió.Cristo, luego de su muerte y resurrección, descendió y/ha cada niño dio Su bendición, y Su Evangelio a la gente enseñó. Hubo paz, la verdad se vivió. Vienen muchos otros que buscan libres ser, el país optó por recoger. Dice/El Libro de Mormón: En hermandad andad y/el país por la fe heredar. Y/el país por la fe heredar. \n\nEran dos mil jóvenes guerreros con valor; a la guerra fue ron con gran fe en el Señor. Eran justos y contaban con Su protección por cumplir con valor su misión.En los muros una vez profetizó Samuel. Era lamanita y también un hombre fiel. Le lanzaron flechas, pe ro Dios lo protegió. Siempre en rectitud Él vivió.Cristo, luego de su muerte y resurreccion, descendio y/ha cada niño dio Su bendicion, y Su Evangelio a la gente enseño. Hubo paz, la verdad se vivio. Vienen muchos otros que buscan libres ser, a los cuales el país optó por recoger. Dice/El Libro de Mormón: En hermandad andad y/el país por la fe heredar. Y/el país por la fe heredar. \n\nEran dos mil jovenes guerreros con valor; a la guerra fueron con gran fe en el Señor. Eran justos y contaban con Su proteccion por cumplir con valor su mision. En los muros una vez profetizó Samuel. Era lamanita y también un hombre fiel. Le lanzaron flechas, pero Dios lo protegió. Siempre en rectitud Él vivió.Cristo, luego de su muerte y resurreccion, descendio y/ha cada niño dio Su Bendicion, y Su Evangelio a la gente enseño. Hubo paz, la verdad se vivio.Vienen muchos otros que buscan libres ser, a los cuales el país optó por recoger. Dice/El Libro de Mormón: En hermandad andad y/el país por la fe heredar. Y/el país por la fe heredar.","measures":49,"mscoreVersion":"0.9.6.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":7,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.soprano","isVisible":"true","lyricCount":196,"name":"<font face=\"Times New Roman\"/>Soprano","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.alto","isVisible":"true","lyricCount":196,"name":"<font face=\"Times New Roman\"/>Alto","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.tenor","isVisible":"true","lyricCount":200,"name":"<font face=\"Times New Roman\"/>Tenor","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.bass","isVisible":"true","lyricCount":200,"name":"<font face=\"Times New Roman\"/>Bajo","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"Letra y Música de Elizabeth Fetzer\nAdaptación para Coro y Pia ...
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102725.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102725.mscx...
# (process_chunk pid=237238) Exit code: 0
# (process_chunk pid=237238) Result: {
# (process_chunk pid=237238) "metadata": {"composer":"Cody J. Olszewski","duration":27,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":12,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"N/A","previousSource":"","subtitle":"The Greatest Musical Score Ever","tempo":105,"tempoText":"<font face=\"Times New Roman\"/><b>Moderato</b>","textFramesData":{"composers":["Cody J. Olszewski"],"poets":["N/A"],"subtitles":["The Greatest Musical Score Ever"],"titles":["Cody's Project 1"]},"timesig":"4/4","title":"Cody's Project 1"}
# (process_chunk pid=237238) }
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) text style <12> not known
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101168.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101168.mscx...
# (process_chunk pid=237237) Exit code: 1
# (process_chunk pid=237237) Result:
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) QZip: not a zip file!
# (process_chunk pid=237237) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1025421.mscz:
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100854.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100854.mscx...
# (process_chunk pid=237236) Exit code: 1
# (process_chunk pid=237236) Result:
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) QZip: not a zip file!
# (process_chunk pid=237236) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1014026.mscz:
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1030661.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1030661.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"","duration":187,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":4,"lyrics":"My soul whispers Thy name.The light that scatters darkness fades all my hopelessness Deepening faith is naught Lordthat You would comfort me Lord break darkness Light will break darkness and God will save His children from the hand of the oppressor For Thee we wait God My Lord my God My soul is torn and shattered My soul is torn and shattered Save me Yahweh Oh Lord For Thee we wait Oh when will You save me from the depths of There is light that will shatter him God this is my cry When Your glory comes Your splendor only You are God Lord glory has come \n\nMy soul whispers Thy name.The light that scatters darkness fades all my hopelessness Deepening faith is naught Lordthat You would comfort me Light break darkness Light break darkness Light will break darkness and God will save His children from the hand of the oppressor For Thee we wait God My Lord my God My soul is torn and shattered My soul is torn and shattered Save me Yahweh Lord For Thee we wait Oh when You save me from the depths of my oppressor's hand There is light that will shatter him God this is my cry to You Lord When Your glory comes splendor is here God only You are Lord Your glory has come \n\nMy soul whispers Thy name. The light that scatters darknessfades into all my hopelessness Deepening deepening though my faith is naught I need Your rest O Lord break darkness God save us from the oppressor For Thee we wait God My Lord my God My soul is trapped in the hands of the oppressor Lord save me from the hands of the oppresor My soul is trapped in the hands of the oppressor My soul is trapped in the hands of the oppressor Oh Lord save me Oh Lord save me He wont let me go he wont let me go he wont let me go he wont let me go he wont let me Oh Lord For Thee we wait Oh when You save me from the depths of his hand There is light that will shatter him God help Your children When Your glory comes Your splendor is here God only You are God Lord Your glory has come \n\nMy soul whispers Thy name. The light that scatters darkness fades into all my hopelessness Deepening though my faith is naught I need Your rest O Lord break darkness God save us from the oppressor For Thee we wait God My Lord my God My soul is torn and shattered My soul is torn and shattered Save me He wont let me go he wont let me go he wont let me go he wont let me go he wont let me go For Thee we wait Oh when You save me There is light that will shatter him God help your children When Your glory comes splendor is here only You are God Lord glory has come","measures":93,"mscoreVersion":"0.9.6.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":9,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.soprano","isVisible":"true","lyricCount":132,"name":"<font size=\"14.5261\"/><font face=\"Times New Roman\"/>Soprano","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.alto","isVisible":"true","lyricCount":142,"name":"<font size=\"14.5261\"/><font face=\"Times New Roman\"/>Alto","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.tenor","isVisible":"true","lyricCount":189,"name":"<font size=\"14.5261\"/><font face=\"Times New Roman\"/>Tenor","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.bass","isVisible":"true","lyricCount":137,"name":"<font size=\"14.5261\"/><font face=\"Times New Roman\"/>Bass","program":52}],"poet":"","previousSource":"","subtitle":"The Coming of Your Glory","tempo":100,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":["The Coming of Your Glory"],"titles":["We Await"]},"timesig":"4/4","title":"We Await"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# ...
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) text style <12> not known
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1029476.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1029476.mscx...
# (process_chunk pid=237242) Exit code: 1
# (process_chunk pid=237242) Result:
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) QZip: not a zip file!
# (process_chunk pid=237242) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1018096.mscz:
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1014116.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1014116.mscx...
# (process_chunk pid=237241) Exit code: 1
# (process_chunk pid=237241) Result:
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) QZip: not a zip file!
# (process_chunk pid=237241) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102669.mscz:
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020831.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020831.mscx...
# (process_chunk pid=237237) Exit code: 1
# (process_chunk pid=237237) Result:
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) QZip: not a zip file!
# (process_chunk pid=237237) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1034766.mscz:
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1021436.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1021436.mscx...
# (process_chunk pid=237235) Exit code: 0
# (process_chunk pid=237235) Result: {
# (process_chunk pid=237235) "metadata": {"composer":"","duration":40,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":32,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"","program":0}],"poet":"","previousSource":"","subtitle":"Peça da Suite: CARNAVAL","tempo":144,"tempoText":"<font face=\"Times New Roman\"/><b>Allegro (M.M. 144)</b>","textFramesData":{"composers":[],"poets":[],"subtitles":["Peça da Suite: CARNAVAL"],"titles":["A Colombina"]},"timesig":"3/4","title":"A Colombina"}
# (process_chunk pid=237235) }
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1033231.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1033231.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"","duration":166,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"true","keysig":1,"lyrics":"두 만 강 푸른 물에 노 젓 는 뱃사 공을 볼수 는없엇 지 만 그 노 래 만은너 무 잘 아 는 건 내 아 버 지레 파 토리그 중 에십 팔 번이 기 때 문 에십 팔 번 이기 때 문에고 향 생 각 나실 때 면 소 주 가 필 요 하 다하 시 고 눈 물 로 지 새 우 시 던내 아 버 지이 렇 게 애 기 해 죠 죽 기 전 에 꼭 한 번 만 이라 도가 봐 으 면좋 게 구나 라 구 요 눈 보 라 휘날 리는 바 람 찬 흥남 부두 가 지 는 못햇 지 만그 노 래 만은너 무 잘 아 는 건내 어 머 니레 파 토리그 중 에십 팔 번이 기 때 문 에십 팔 번 이기 때 문에남 은 인 생 남앗 으 면얼 마 나 남 앗 겟 니하 시 고눈 물 로 지 새 우 시 던내 어 머 니","measures":42,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":208,"name":"Electric Guitar","program":27}],"poet":"","previousSource":"","subtitle":"","tempo":120,"tempoText":"<sym>metNoteQuarterUp</sym><sym>space</sym><sym>metAugmentationDot</sym> = 80","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["라구요"]},"timesig":"4/4","title":"라구요"}
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101769.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101769.mscx...
# (process_chunk pid=237236) Exit code: 0
# (process_chunk pid=237236) Result: {
# (process_chunk pid=237236) "metadata": {"composer":"Francesc Bitlloch","duration":41,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"true","keysig":1,"lyrics":"Se'l veu volar entre garrics iarboços voladora sagetaquees dispara, del castell d'Arria baixa la riba, atravessa la tet d'una gambada. Quan trobaun cinglealtívol, el voreja, quan trobaun còrrec famolenc el salta, per l'arrelam del Canigó se'n puja vers on blanquegen els mantells estesos ien un pradell al cim de la carena Gentil veu una reina coronada.","measures":14,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.vocals","isVisible":"true","lyricCount":110,"name":"Veu","program":52}],"poet":"","previousSource":"","subtitle":"Les cançons de Canigó","tempo":0,"tempoText":"","textFramesData":{"composers":["Francesc Bitlloch"],"poets":[],"subtitles":["Les cançons de Canigó"],"titles":["Galop"]},"timesig":"4/4","title":"Galop"}
# (process_chunk pid=237236) }
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102759.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102759.mscx...
# (process_chunk pid=237238) Exit code: 0
# (process_chunk pid=237238) Result: {
# (process_chunk pid=237238) "metadata": {"composer":"Säv. Alberto Dominguez\nSov. Jari Komulainen","duration":88,"fileVersion":114,"hasHarmonies":"true","hasLyrics":"false","keysig":0,"lyrics":"","measures":35,"mscoreVersion":"0.9.6.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/><i>I</i>","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/><i>II</i>","program":40},{"harmonyCount":56,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.bass.electric","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/><i>Basso</i>","program":33}],"poet":"","previousSource":"","subtitle":"","tempo":112,"tempoText":"<font face=\"Times New Roman\"/><b>Moderato</b>","textFramesData":{"composers":["Säv. Alberto Dominguez\nSov. Jari Komulainen"],"poets":[],"subtitles":[],"titles":["Perfidia"]},"timesig":"4/4","title":"Perfidia"}
# (process_chunk pid=237238) }
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) text style <26> not known
# (process_chunk pid=237238) text style <26> not known
# (process_chunk pid=237238) text style <26> not known
# (process_chunk pid=237238) text style <26> not known
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020346.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020346.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"Arranged by Tehishter\nTrans. by Bombitmanbomb","duration":49,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":1,"lyrics":"","measures":33,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"Piano","program":0}],"poet":"","previousSource":"https://musescore.com/score/1029476","subtitle":"No Game No Life ED","tempo":168,"tempoText":"<sym>metNoteQuarterUp</sym> = 168","textFramesData":{"composers":["Arranged by Tehishter\nTrans. by Bombitmanbomb"],"poets":[],"subtitles":["No Game No Life ED"],"titles":["Oracion"]},"timesig":"12/8","title":"Oracion"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020556.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020556.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"Arr. by Kdielol","duration":99,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":5,"lyrics":"","measures":35,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.viola","isVisible":"true","lyricCount":0,"name":"Viola","program":41}],"poet":"","previousSource":"","subtitle":"Viola Arrangement","tempo":85,"tempoText":"<sym>metNoteQuarterUp</sym> = 85","textFramesData":{"composers":["Arr. by Kdielol"],"poets":[],"subtitles":["Viola Arrangement"],"titles":["Otonashi"]},"timesig":"4/4","title":"Otonashi"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1031956.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1031956.mscx...
# (process_chunk pid=237237) Exit code: 1
# (process_chunk pid=237237) Result:
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) QZip: not a zip file!
# (process_chunk pid=237237) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1021436.mscz:
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101456.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101456.mscx...

# %%
print(ray.get(futures))
# Out:
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"Written by Daniel Ingram\nArranged by Rudie16 ","duration":82,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":1,"lyrics":"","measures":41,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["Written by Daniel Ingram\nArranged by Rudie16 "],"poets":[],"subtitles":[],"titles":["Failure Success song "]},"timesig":"4/4","title":"Failure Success song "}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102926.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102926.mscx...
# (process_chunk pid=237236) Exit code: 0
# (process_chunk pid=237236) Result: {
# (process_chunk pid=237236) "metadata": {"composer":"David Guetta","duration":196,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-3,"lyrics":"","measures":98,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":8,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano.electric","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Electric Piano","program":4}],"poet":"Arranged By: Rachel McClanahan","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["David Guetta"],"poets":["Arranged By: Rachel McClanahan"],"subtitles":[],"titles":["Titanium"]},"timesig":"4/4","title":"Titanium"}
# (process_chunk pid=237236) }
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1015506.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1015506.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"","duration":12,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":0,"lyrics":"Humpty Dumpty sat on a wall Humpty Dumpty had a great fall All the kings horses and all the king's men couldn't put Humpty together again. Humpty Dumpty sat on a bridge Whilst the army climbed up the ridge couldn't get Humpty to see them again.","measures":8,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":62,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"http://musescore.com/score/973736","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Humpty Dumpty"]},"timesig":"6/8","title":"Humpty Dumpty"}
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102990.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102990.mscx...
# (process_chunk pid=237241) Exit code: 0
# (process_chunk pid=237241) Result: {
# (process_chunk pid=237241) "metadata": {"composer":"Gabriel Joseph Manning Welsh","duration":144,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":44,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello","program":42}],"poet":"","previousSource":"","subtitle":"A new found life","tempo":0,"tempoText":"","textFramesData":{"composers":["Gabriel Joseph Manning Welsh"],"poets":[],"subtitles":["A new found life"],"titles":[]},"timesig":"4/4","title":"101210"}
# (process_chunk pid=237241) }
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102971.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102971.mscx...
# (process_chunk pid=237237) Exit code: 0
# (process_chunk pid=237237) Result: {
# (process_chunk pid=237237) "metadata": {"composer":"Kailas Rajan","duration":218,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":136,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":32,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"false","hasTabStaff":"true","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"Electric Guitar","program":27},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"false","hasTabStaff":"true","instrumentId":"pluck.bass","isVisible":"true","lyricCount":0,"name":"Bass Guitar","program":34},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"Drumset","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"false","hasTabStaff":"true","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"Electric Guitar","program":27}],"poet":"Powertrain","previousSource":"","subtitle":"A trial","tempo":150,"tempoText":"<sym>metNoteQuarterUp</sym> = 150","textFramesData":{"composers":["Kailas Rajan"],"poets":["Powertrain"],"subtitles":["A trial"],"titles":["First Song\n"]},"timesig":"4/4","title":"First Song\n"}
# (process_chunk pid=237237) }
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100356.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100356.mscx...
# (process_chunk pid=237238) Exit code: 0
# (process_chunk pid=237238) Result: {
# (process_chunk pid=237238) "metadata": {"composer":"","duration":56,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":1,"lyrics":"","measures":16,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"","program":73}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["El Rey León  (wimoweh)"]},"timesig":"4/4","title":"El Rey León  (wimoweh)"}
# (process_chunk pid=237238) }
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100089.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100089.mscx...
# (process_chunk pid=237235) Exit code: 0
# (process_chunk pid=237235) Result: {
# (process_chunk pid=237235) "metadata": {"composer":"","duration":609,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":138,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"false","width":210},"pages":29,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.viola","isVisible":"true","lyricCount":0,"name":"Viola","program":41},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"Violoncello","program":42},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.contrabass","isVisible":"true","lyricCount":0,"name":"Contrabass","program":43},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.contrabass","isVisible":"true","lyricCount":0,"name":"Double Bass","program":43},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.viola","isVisible":"true","lyricCount":0,"name":"Viola","program":41},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"Violoncello","program":42},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.contrabass","isVisible":"true","lyricCount":0,"name":"Contrabass","program":43},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.contrabass","isVisible":"true","lyricCount":0,"name":"Double Bass","program":43},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.harp","isVisible":"true","lyricCount":0,"name":"Harp","program":46},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"Drumset","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"drum.timpani","isVisible":"true","lyricCount":0,"name":"Timpani","program":47},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"drum.timpani","isVisible":"true","lyricCount":0,"name":"Timpani","program":47},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.c","isVisible":"true","lyricCount":0,"name":"C Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"Tuba","program":58},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.balalaika","isVisible":"true","lyricCount":0,"name":"Balalaika","program":107},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"synth.pad.warm","isVisible":"true","lyricCount":0,"name":"Warm Synthesizer","program":89 ...
# (process_chunk pid=237235) }
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101160.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101160.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"","duration":79,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":3,"lyrics":"","measures":25,"mscoreVersion":"2.0.2","pageFormat":{"height":279,"twosided":"true","width":216},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":74,"tempoText":"<sym>metNoteQuarterUp</sym> = 74","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":[]},"timesig":"4/4","title":"wegdgag"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100465.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100465.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"","duration":110,"fileVersion":114,"hasHarmonies":"true","hasLyrics":"false","keysig":-1,"lyrics":"","measures":41,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":9,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Tenor Saxophone","program":66}],"poet":"","previousSource":"http://wikifonia.org/node/15734/revisions/27163/view","subtitle":"(Bb/Tenor Sax)","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":["(Bb/Tenor Sax)"],"titles":["Pick Up The Pieces"]},"timesig":"4/4","title":"Pick Up The Pieces"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1027541.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1027541.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"","duration":64,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":32,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Electric Guitar","program":27}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Hexatonic Study"]},"timesig":"4/4","title":"Hexatonic Study"}
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1028361.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1028361.mscx...
# (process_chunk pid=237236) Exit code: 0
# (process_chunk pid=237236) Result: {
# (process_chunk pid=237236) "metadata": {"composer":"Roger Hoffman","duration":218,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":64,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":3,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"http://musescore.com/score/70680","subtitle":"","tempo":70,"tempoText":"<font face=\"Times New Roman\"/><b>Introspectively</b>","textFramesData":{"composers":["Roger Hoffman","Composed By Roger Hoffman"],"poets":[],"subtitles":[],"titles":["Consider The Lilies of the Field"]},"timesig":"4/4","title":"Consider The Lilies of the Field"}
# (process_chunk pid=237236) }
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) text style <12> not known
# (process_chunk pid=237236) text style <26> not known
# (process_chunk pid=237236) text style <26> not known
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1031691.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1031691.mscx...
# (process_chunk pid=237237) Exit code: 1
# (process_chunk pid=237237) Result:
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) QZip: not a zip file!
# (process_chunk pid=237237) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100356.mscz:
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101598.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101598.mscx...
# (process_chunk pid=237238) Exit code: 1
# (process_chunk pid=237238) Result:
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) QZip: not a zip file!
# (process_chunk pid=237238) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100089.mscz:
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102728.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102728.mscx...
# (process_chunk pid=237235) Exit code: 0
# (process_chunk pid=237235) Result: {
# (process_chunk pid=237235) "metadata": {"composer":"","duration":48,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":24,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bass","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Bass Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.vocals","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Mezzosoprano","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.baritone","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Baritone","program":52}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Over The Misty Mountains Cold"]},"timesig":"4/4","title":"Over The Misty Mountains Cold"}
# (process_chunk pid=237235) }
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1019686.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1019686.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Natalie \"Nat\" Zarasian"]},"timesig":"4/4","title":"Natalie \"Nat\" Zarasian"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1025686.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1025686.mscx...
# (process_chunk pid=237241) Exit code: 0
# (process_chunk pid=237241) Result: {
# (process_chunk pid=237241) "metadata": {"composer":"by Nina Simone\narr. Romain P.","duration":191,"fileVersion":114,"hasHarmonies":"true","hasLyrics":"false","keysig":0,"lyrics":"","measures":69,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":34,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":11,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Alto Saxophone","program":65},{"harmonyCount":4,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Baritone Saxophone","program":67},{"harmonyCount":5,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.cornet.soprano","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>B<font size=\"14.8538\"/><font face=\"MScore1\"/><sym>accidentalFlat</sym><font size=\"12.3782\"/><font face=\"Times New Roman\"/> Trumpet","program":56},{"harmonyCount":2,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone.bass","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Bass Trombone","program":57},{"harmonyCount":35,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Electric Guitar","program":27},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.bass.electric","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Electric Bass","program":33},{"harmonyCount":45,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Drumset","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":132,"tempoText":"<sym>metNoteQuarterUp</sym> = 132","textFramesData":{"composers":["by Nina Simone\narr. Romain P."],"poets":[],"subtitles":[],"titles":["Feeling Good"]},"timesig":"12/8","title":"Feeling Good"}
# (process_chunk pid=237241) }
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) text style <12> not known
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1028901.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1028901.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"Pierre-Adrien LANGROGNET","duration":80,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":40,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":6,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"http://musescore.com/score/1025866","subtitle":"en Ré mineur","tempo":0,"tempoText":"","textFramesData":{"composers":["Pierre-Adrien LANGROGNET"],"poets":[],"subtitles":["en Ré mineur"],"titles":["Un triste rêve"]},"timesig":"4/4","title":"Un triste rêve"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1004.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1004.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"Lady Gaga","duration":96,"fileVersion":206,"hasHarmonies":"true","hasLyrics":"false","keysig":5,"lyrics":"","measures":26,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":4,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"Electric Guitar","program":27}],"poet":"","previousSource":"https://musescore.com/score/1028361","subtitle":"Form: Intro, A, B, A, C, B, D","tempo":0,"tempoText":"","textFramesData":{"composers":["Lady Gaga"],"poets":[],"subtitles":["Form: Intro, A, B, A, C, B, D"],"titles":["Poker Face"]},"timesig":"4/4","title":"Poker Face"}
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/103519.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/103519.mscx...
# (process_chunk pid=237236) Exit code: 1
# (process_chunk pid=237236) Result:
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) QZip: not a zip file!
# (process_chunk pid=237236) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1031691.mscz:
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1021251.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1021251.mscx...
# (process_chunk pid=237238) Exit code: 1
# (process_chunk pid=237238) Result:
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) QZip: not a zip file!
# (process_chunk pid=237238) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102728.mscz:
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1013.mscx...
# (process_chunk pid=237237) Exit code: 1
# (process_chunk pid=237237) Result:
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) QZip: not a zip file!
# (process_chunk pid=237237) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101598.mscz:
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1031006.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1031006.mscx...
# (process_chunk pid=237235) Exit code: 0
# (process_chunk pid=237235) Result: {
# (process_chunk pid=237235) "metadata": {"composer":"Franz Schubert","duration":132,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":4,"lyrics":"Am Brunnen vor em Thore da steht ein Lindenbaum; ich träumt' in seinem Schatten so manchen süssen Traum. Ich schnitt in seine Rinde so manches liebe Wort; es zog in Freund' und Leide zu ihmmich immer fort. Ich musst' auch heute wandern vorbei in tiefer Nacht, da hab' ich noch im Dunkel die Augen zugemacht. Und seine Zweige rauschten, als riefen sie mir zu: komm her zu mir, Geselle, hier find'st du deine Ruh! Die kalten Winde bliesen mir grad' in's Angesicht, der Hut flog mir vom Kopfe, ich wendete mich nicht. Nun bin ich manche Stunde entfernt von jenem Ort, und immer hör' ich's rauschen! du fändest Ruhe dort! Nun bin ich manche Stunde entfernt von jenem Ort, und immer hör' ich's rauschen: du fändest Ruhe dort, du fändest Ruhe dort!","measures":82,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":22,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.vocals","isVisible":"true","lyricCount":189,"name":"<font face=\"Times New Roman\"/>Voice","program":52},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":112,"tempoText":"<font face=\"Times New Roman\"/><b>Mäßig</b>","textFramesData":{"composers":["Franz Schubert"],"poets":[],"subtitles":[],"titles":["Der Lindenbaum"]},"timesig":"3/4","title":"Der Lindenbaum"}
# (process_chunk pid=237235) }
# (process_chunk pid=237235) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237235) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237235) Creating main window…
# (process_chunk pid=237235) Reading translations…
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) text style <12> not known
# (process_chunk pid=237235) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100179.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100179.mscx...
# (process_chunk pid=237240) Exit code: 0
# (process_chunk pid=237240) Result: {
# (process_chunk pid=237240) "metadata": {"composer":"Sorahya Woods","duration":128,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-3,"lyrics":"","measures":64,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":3,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.oboe","isVisible":"true","lyricCount":0,"name":"Oboe","program":68},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.bassoon","isVisible":"true","lyricCount":0,"name":"Bassoon","program":70}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["Sorahya Woods"],"poets":[],"subtitles":[],"titles":["Why???"]},"timesig":"4/4","title":"Why???"}
# (process_chunk pid=237240) }
# (process_chunk pid=237240) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237240) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237240) Creating main window…
# (process_chunk pid=237240) Reading translations…
# (process_chunk pid=237240) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100423.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100423.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"Modeste Moussorgsky","duration":70,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-2,"lyrics":"","measures":24,"mscoreVersion":"0.9.6.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"","program":0}],"poet":"","previousSource":"","subtitle":"Promenade","tempo":120,"tempoText":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/><b>Allegro giusto, nel modo russico; senza allegrezza, ma poco sostenuto.</b>","textFramesData":{"composers":["Modeste Moussorgsky"],"poets":[],"subtitles":["Promenade"],"titles":["Bilder einer Ausstellung"]},"timesig":"5/4","title":"Bilder einer Ausstellung"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) text style <12> not known
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1023106.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1023106.mscx...
# (process_chunk pid=237241) Exit code: 0
# (process_chunk pid=237241) Result: {
# (process_chunk pid=237241) "metadata": {"composer":"","duration":154,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":3,"lyrics":"","measures":50,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":22,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 1","program":49},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 2","program":51},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 3","program":116},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 5","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute.piccolo","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 6","program":72},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.panpipes","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 7","program":75},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.harp","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 7","program":46},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 8","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"drum.timpani","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Track 9","program":47}],"poet":"","previousSource":"","subtitle":"","tempo":78,"tempoText":"<sym>metNoteQuarterUp</sym> = 78","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":[]},"timesig":"4/4","title":"1028901"}
# (process_chunk pid=237241) }
# (process_chunk pid=237241) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237241) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237241) Creating main window…
# (process_chunk pid=237241) Reading translations…
# (process_chunk pid=237241) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102223.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102223.mscx...
# (process_chunk pid=237236) Exit code: 0
# (process_chunk pid=237236) Result: {
# (process_chunk pid=237236) "metadata": {"composer":"","duration":39,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-3,"lyrics":"","measures":17,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.organ","isVisible":"true","lyricCount":0,"name":"Organ","program":19}],"poet":"","previousSource":"https://musescore.com/score/1021251","subtitle":"\"A Man shall be as an hiding place from the wind and a covert from the tempest.\"","tempo":160,"tempoText":"<sym>metNoteHalfUp</sym> = 80","textFramesData":{"composers":[],"poets":[],"subtitles":["\"A Man shall be as an hiding place from the wind and a covert from the tempest.\""],"titles":["Hymn 179"]},"timesig":"4/2","title":"Hymn 179"}
# (process_chunk pid=237236) }
# (process_chunk pid=237236) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237236) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237236) Creating main window…
# (process_chunk pid=237236) Reading translations…
# (process_chunk pid=237236) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1032626.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1032626.mscx...
# (process_chunk pid=237238) Exit code: 1
# (process_chunk pid=237238) Result:
# (process_chunk pid=237238) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237238) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237238) Creating main window…
# (process_chunk pid=237238) Reading translations…
# (process_chunk pid=237238) QZip: not a zip file!
# (process_chunk pid=237238) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013.mscz:
# (process_chunk pid=237238) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102551.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102551.mscx...
# (process_chunk pid=237239) Exit code: 0
# (process_chunk pid=237239) Result: {
# (process_chunk pid=237239) "metadata": {"composer":"Brittany McCrea","duration":112,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":2,"lyrics":"","measures":41,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["Brittany McCrea"],"poets":[],"subtitles":[],"titles":["Sonata Project"]},"timesig":"4/4","title":"Sonata Project"}
# (process_chunk pid=237239) }
# (process_chunk pid=237239) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237239) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237239) Creating main window…
# (process_chunk pid=237239) Reading translations…
# (process_chunk pid=237239) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102540.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102540.mscx...
# (process_chunk pid=237237) Exit code: 0
# (process_chunk pid=237237) Result: {
# ...
# (process_chunk pid=237237) Exit code: 1
# (process_chunk pid=237237) Result:
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) QZip: not a zip file!
# (process_chunk pid=237237) Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1021121.mscz:
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1034371.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1034371.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"","duration":64,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":0,"lyrics":"S o n o r a R o s e S c h e v e n","measures":32,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":17,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Sonora in Name"]},"timesig":"4/4","title":"Sonora in Name"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/10296.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/10296.mscx...
# (process_chunk pid=237237) Exit code: 0
# (process_chunk pid=237237) Result: {
# (process_chunk pid=237237) "metadata": {"composer":"Mark Ronson arr. Ethan Hamilton","duration":108,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":52,"mscoreVersion":"2.0.1","pageFormat":{"height":279,"twosided":"true","width":216},"pages":19,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute.piccolo","isVisible":"true","lyricCount":0,"name":"Piccolo","program":72},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"Baritone Saxophone","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.euphonium","isVisible":"true","lyricCount":0,"name":"Euphonium","program":58},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"B♭ Tuba","program":58},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"Drumset","program":0}],"poet":"","previousSource":"","subtitle":"for Marching Band","tempo":116,"tempoText":"<sym>metNoteQuarterUp</sym> = 116","textFramesData":{"composers":["Mark Ronson arr. Ethan Hamilton"],"poets":[],"subtitles":["for Marching Band"],"titles":["Uptown Funk"]},"timesig":"4/4","title":"Uptown Funk"}
# (process_chunk pid=237237) }
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100981.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100981.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"E.Elger","duration":100,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":2,"lyrics":"","measures":100,"mscoreVersion":"0.9.6.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello1","program":42},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello2","program":42},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello3","program":42},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello4","program":42}],"poet":"","previousSource":"","subtitle":"チェロアンサンブル","tempo":0,"tempoText":"","textFramesData":{"composers":["E.Elger"],"poets":[],"subtitles":["チェロアンサンブル"],"titles":["愛の挨拶"]},"timesig":"2/4","title":"愛の挨拶"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1017326.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1017326.mscx...
# (process_chunk pid=237237) Exit code: 0
# (process_chunk pid=237237) Result: {
# (process_chunk pid=237237) "metadata": {"composer":"Josh Fulford","duration":135,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":-2,"lyrics":"","measures":59,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":19,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.cornet.soprano","isVisible":"true","lyricCount":0,"name":"<font size=\"14.1017\"/><font face=\"Times New Roman\"/>B<font face=\"MScore1\"/><sym>accidentalFlat</sym><font face=\"Times New Roman\"/> Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.bass.fretless","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Fretless Electric Bass","program":35},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Drumset","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":64,"tempoText":"<font face=\"Times New Roman\"/><b>Largo</b>","textFramesData":{"composers":["Josh Fulford"],"poets":[],"subtitles":[],"titles":["Chameleon"]},"timesig":"4/4","title":"Chameleon"}
# (process_chunk pid=237237) }
# (process_chunk pid=237237) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237237) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237237) Creating main window…
# (process_chunk pid=237237) Reading translations…
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) text style <12> not known
# (process_chunk pid=237237) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1028526.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1028526.mscx...
# (process_chunk pid=237242) Exit code: 0
# (process_chunk pid=237242) Result: {
# (process_chunk pid=237242) "metadata": {"composer":"","duration":64,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":1,"lyrics":"","measures":41,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.duduk","isVisible":"false","lyricCount":0,"name":"","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.duduk","isVisible":"false","lyricCount":0,"name":"","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.duduk","isVisible":"true","lyricCount":0,"name":"","program":71}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Happy Birthday - Variationen"]},"timesig":"3/4","title":"Happy Birthday - Variationen"}
# (process_chunk pid=237242) }
# (process_chunk pid=237242) Errors: /lib/x86_64-linux-gnu/libjack.so.0
# (process_chunk pid=237242) /lib/x86_64-linux-gnu/libnss3.so
# (process_chunk pid=237242) Creating main window…
# (process_chunk pid=237242) Reading translations…
# (process_chunk pid=237242) Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101561.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101561.mscx...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_236945/943246807.py in <module>
# ----> 1 print(ray.get(futures))
#
# ~/anaconda3/lib/python3.8/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/ray/_private/worker.py in get(object_refs, timeout)
#    2281
#    2282         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2283         values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2284         for i, value in enumerate(values):
#    2285             if isinstance(value, RayError):
#
# ~/anaconda3/lib/python3.8/site-packages/ray/_private/worker.py in get_objects(self, object_refs, timeout)
#     666
#     667         timeout_ms = int(timeout * 1000) if timeout else -1
# --> 668         data_metadata_pairs = self.core_worker.get_objects(
#     669             object_refs, self.current_task_id, timeout_ms
#     670         )
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.get_objects()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
# for i, entry in enumerate(os.scandir(SAMPLE_FOLDER)):
#     if i == 10:
#         break
#     ID, file_extension = os.path.splitext(entry.name)
#     converted_file_path = os.path.join(CONVERSION_FOLDER, ID + '.mscx')
#     print(f"Converting {entry.path} to {converted_file_path}...", end=' ')
    
#     result = subprocess.run([musescore_cmd,"--score-meta", "-o", converted_file_path, entry.path], capture_output=True, text=True)
#     print(f"Exit code: {result.returncode}")
#     print(f"Result: {result.stdout.strip()}") # the extraction of metadata as JSON does not work on Windows; please store the JSON to the metadata output folder
#     print(f"Errors: {result.stderr.strip()}")
# Out:
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100462.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100462.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Erin Taylor Nicole"]},"timesig":"4/4","title":"Erin Taylor Nicole"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020611.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020611.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"Arr. Raven Simon","duration":79,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":48,"mscoreVersion":"2.0.0","pageFormat":{"height":279,"twosided":"false","width":216},"pages":7,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bass","isVisible":"true","lyricCount":0,"name":"Bass Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"Baritone Saxophone","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"Tuba","program":58},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.marimba","isVisible":"true","lyricCount":0,"name":"Marimba","program":12},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.vibraphone","isVisible":"true","lyricCount":0,"name":"Vibraphone","program":11},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.xylophone","isVisible":"true","lyricCount":0,"name":"Xylophone","program":13},{"harmonyCount":0,"hasDrumStaff":"fal ...
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1035766.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1035766.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["#9 Bass Cleff song #3"]},"timesig":"4/4","title":"#9 Bass Cleff song #3"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1014811.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1014811.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"JAVIER BARANDIARAN URIARTE","duration":28,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":14,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.c","isVisible":"true","lyricCount":0,"name":"Trompeta en Do","program":56},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"Set de percusión","program":0},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"metal.cymbal.crash","isVisible":"true","lyricCount":0,"name":"Platillos","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["JAVIER BARANDIARAN URIARTE"],"poets":[],"subtitles":[],"titles":["TOQUE MILITAR"]},"timesig":"4/4","title":"TOQUE MILITAR"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013421.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1013421.mscx... Exit code: 1
# Result:
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# QZip: not a zip file!
# Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013421.mscz:
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102669.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102669.mscx... Exit code: 1
# Result:
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# QZip: not a zip file!
# Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102669.mscz:
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020831.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020831.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"","duration":109,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":-3,"lyrics":"Ohthere's no place like home. 'Midpleasuressures and palaces throughwe may roam. Be it ever so humble there's noplace like home. A charmfrom the skies seems to hallow us there, which seekthrough the world is not metwith elsewhere. Oh there's noplace like home, Oh there's noplace like home, \n\nOhthere's no place likehome. Be it ever so humble there's noplace like home. A charmfrom the skies seems to hallow us there, which seek through the world is not met with elsewhere. Oh there's no place like home, Oh there's no place like home. \n\nA charmfrom the skies seems to hallow us there, which seekthrough the world is not metwith elsewhere. Home, home sweet home, Oh there's no place like home. Oh there's no place like home. \n\nHome, home sweet home, Oh there'sno place like home. Oh there's no place like home. \n\nWhich seekthrough the worldis not metwith elsewhere. Homehome sweet home, Oh there's no place like home. Oh there's noplace like home. \n\nHome, home sweet home, Ohthere's no place like home. Oh there's noplace like home.","measures":91,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":5,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.soprano","isVisible":"true","lyricCount":63,"name":"<font face=\"Times New Roman\"/>Soprano","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.soprano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Soprano","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.alto","isVisible":"true","lyricCount":52,"name":"<font face=\"Times New Roman\"/>Alto","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.alto","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Alto","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.tenor","isVisible":"true","lyricCount":38,"name":"<font face=\"Times New Roman\"/>Tenor","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.tenor","isVisible":"true","lyricCount":16,"name":"<font face=\"Times New Roman\"/>Tenor","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.bass","isVisible":"true","lyricCount":27,"name":"<font face=\"Times New Roman\"/>Bass","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.bass","isVisible":"true","lyricCount":16,"name":"<font face=\"Times New Roman\"/>Bass","program":67}],"poet":"","previousSource":"","subtitle":"","tempo":160,"tempoText":"<font face=\"Times New Roman\"/><b>Presto</b>","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Home"]},"timesig":"4/4","title":"Home"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1031601.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1031601.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"Lucy Berman","duration":53,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":4,"lyrics":"","measures":32,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"Seal","previousSource":"","subtitle":"Triple Trio","tempo":144,"tempoText":"<font face=\"Times New Roman\"/><b>Vivace</b>","textFramesData":{"composers":["Lucy Berman"],"poets":["Seal"],"subtitles":["Triple Trio"],"titles":["Kiss From a Rose"]},"timesig":"4/4","title":"Kiss From a Rose"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101210.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101210.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"Gabriel Joseph Manning Welsh","duration":144,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":44,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello","program":42}],"poet":"","previousSource":"","subtitle":"A new found life","tempo":0,"tempoText":"","textFramesData":{"composers":["Gabriel Joseph Manning Welsh"],"poets":[],"subtitles":["A new found life"],"titles":[]},"timesig":"4/4","title":"101210"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102971.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102971.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"by Nina Simone\narr. Romain P.","duration":191,"fileVersion":114,"hasHarmonies":"true","hasLyrics":"false","keysig":0,"lyrics":"","measures":69,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":34,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":11,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Alto Saxophone","program":65},{"harmonyCount":4,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Baritone Saxophone","program":67},{"harmonyCount":5,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.cornet.soprano","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>B<font size=\"14.8538\"/><font face=\"MScore1\"/><sym>accidentalFlat</sym><font size=\"12.3782\"/><font face=\"Times New Roman\"/> Trumpet","program":56},{"harmonyCount":2,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone.bass","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Bass Trombone","program":57},{"harmonyCount":35,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Electric Guitar","program":27},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.bass.electric","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Electric Bass","program":33},{"harmonyCount":45,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Drumset","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":132,"tempoText":"<sym>metNoteQuarterUp</sym> = 132","textFramesData":{"composers":["by Nina Simone\narr. Romain P."],"poets":[],"subtitles":[],"titles":["Feeling Good"]},"timesig":"12/8","title":"Feeling Good"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known

# %% [markdown]
# Using the ms3 parsing library to extract score information:

# %%
for entry in os.scandir(CONVERSION_FOLDER):
    if entry.is_dir():
        continue
    parsed = ms3.Score(entry.path, read_only=True)
    ID, _ = os.path.splitext(entry.name)
    tsv_name = f"{ID}.tsv"
    dataframes = dict(
        events = parsed.mscx.events(),
        notes = parsed.mscx.notes(),
        measures = parsed.mscx.measures(),
        labels = parsed.mscx.labels(),
    )
    for facet, df in dataframes.items():
        if df is None:
            continue
        tsv_path = os.path.join(OUTPUT_PATHS[facet], tsv_name)
        df.to_csv(tsv_path, sep='\t', index=False)
    metadata = parsed.mscx.metadata # please add this nested dictionary to the JSON stored in the previous step
    metadata['id'] = ID
# Out:
# INCORRECT_VOLTA_MN_WARNING (2, 15) ms3.Score.100027.mscx -- c:\users\hentsche\pycharmprojects\ms3\src\ms3\bs4_measures.py (line 184) check_measure_numbers():
# 	MC 15, the 1st measure of a 2nd volta, should have MN 14, not MN 15.
