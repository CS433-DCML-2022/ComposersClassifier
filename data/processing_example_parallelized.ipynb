# %% [markdown]
# Please use the current development version and report any bugs you encounter:
# `pip install git+https://github.com/johentsch/ms3.git@corpus_structure`

# %%
import os, shutil, subprocess
import ms3
import ray
# Out:
# DEBUG:ray:[ray] Forcing OMP_NUM_THREADS=1 to avoid performance degradation with many workers (issue #6998). You can override this by explicitly setting OMP_NUM_THREADS.

# %%
### Arch-Dependant parameters to check

DATA_FOLDER = os.path.abspath('./mscz')
# DATA_FOLDER = os.path.abspath('/scratch/data/musescore.com/') # on the HPC: /scratch/data/musescore.com/
MUSESCORE_CMD = ms3.get_musescore('auto')
# MUSESCORE_CMD = "/usr/local/bin/AppImg???"
# MUSESCORE_CMD = "/home/erwan/.local/bin/MuseScore-3.6.2.548021370-x86_64.AppImage"

# %%
NB_THREADS=32
MSCZ_FILENAMES=os.listdir(DATA_FOLDER)

CONVERSION_FOLDER = os.path.abspath('./mscx')
OUTPUT_PATHS = dict(
    events = os.path.abspath('./events'),
    notes = os.path.abspath('./notes'),
    measures = os.path.abspath('./measures'),
    labels = os.path.abspath('./labels'),
    metadata = os.path.abspath('./metadata'),
)

# %% [markdown]
# Using the MuseScore 3 binary to convert the file format to the current version of MuseScore 3 (needs to be installed or available as AppImage). [MuseScore commandline options](https://musescore.org/en/handbook/3/command-line-options)
#
# ToDos:
#
# * parallelize the conversion (anyone interested in learning [ray](https://www.ray.io/)?)
# * avoid processing files more than once, making use of the fact that the file names correspond to IDs
# * add proper error handling, keeping track of a mapping ID -> `errors message` for files that cannot successfully be converted (checkout stdout and stderr arguments of [subprocess.run()](https://docs.python.org/3/library/subprocess.html#subprocess.run))

# %%
ray.init(ignore_reinit_error=True)
# Out:
# 2022-11-30 10:33:25,818	INFO worker.py:1528 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.8', ray_version='2.1.0', ray_commit='be49bde7ee4f6adb3f8710aee0665c27f9f0bb62', address_info={'node_ip_address': '128.179.152.52', 'raylet_ip_address': '128.179.152.52', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-11-30_10-33-17_838079_5426/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-11-30_10-33-17_838079_5426/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2022-11-30_10-33-17_838079_5426', 'metrics_export_port': 62431, 'gcs_address': '128.179.152.52:43537', 'address': '128.179.152.52:43537', 'dashboard_agent_listen_port': 52365, 'node_id': 'f471234606be4afd18564aacef7412d40d08fdc4a8eb902e36834622'})

# %%
@ray.remote
def process_chunk(filenames):
    for i, filename in enumerate(filenames):
        ID, file_extension = os.path.splitext(filename)
        converted_file_path = os.path.join(CONVERSION_FOLDER, ID + '.mscx')
        file_path = os.path.join(SAMPLE_FOLDER, filename)
        print(f"Converting {file_path} to {converted_file_path}...", end=' ')
        
        result = subprocess.run([musescore_cmd,"--score-meta", "-o", converted_file_path, file_path], capture_output=True, text=True)
        print(f"Exit code: {result.returncode}")
        print(f"Result: {result.stdout.strip()}") # the extraction of metadata as JSON does not work on Windows; please store the JSON to the metadata output folder
        print(f"Errors: {result.stderr.strip()}")

# %%
threads=32
files=os.listdir(SAMPLE_FOLDER)
n=len(files)
futures = [process_chunk.remote(files[i*(n//threads):min((i+1)*(n//threads),n)]) for i in range (threads)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [41], line 4
#       2 files=os.listdir(SAMPLE_FOLDER)
#       3 n=len(files)
# ----> 4 futures = [process_chunk.remote(files[i*(n//threads):min((i+1)*(n//threads),n)]) for i in range (threads)]
#
# Cell In [41], line 4, in <listcomp>(.0)
#       2 files=os.listdir(SAMPLE_FOLDER)
#       3 n=len(files)
# ----> 4 futures = [process_chunk.remote(files[i*(n//threads):min((i+1)*(n//threads),n)]) for i in range (threads)]
#
# File ~/.local/lib/python3.10/site-packages/ray/remote_function.py:122, in RemoteFunction.__init__.<locals>._remote_proxy(*args, **kwargs)
#     120 @wraps(function)
#     121 def _remote_proxy(*args, **kwargs):
# --> 122     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#
# File ~/.local/lib/python3.10/site-packages/ray/util/tracing/tracing_helper.py:307, in _tracing_task_invocation.<locals>._invocation_remote_span(self, args, kwargs, *_args, **_kwargs)
#     305     if kwargs is not None:
#     306         assert "_ray_trace_ctx" not in kwargs
# --> 307     return method(self, args, kwargs, *_args, **_kwargs)
#     309 assert "_ray_trace_ctx" not in kwargs
#     311 tracer = _opentelemetry.trace.get_tracer(__name__)
#
# File ~/.local/lib/python3.10/site-packages/ray/remote_function.py:402, in RemoteFunction._remote(self, args, kwargs, **task_options)
#     399 if self._decorator is not None:
#     400     invocation = self._decorator(invocation)
# --> 402 return invocation(args, kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/remote_function.py:369, in RemoteFunction._remote.<locals>.invocation(args, kwargs)
#     367     list_args = []
#     368 else:
# --> 369     list_args = ray._private.signature.flatten_args(
#     370         self._function_signature, args, kwargs
#     371     )
#     373 if worker.mode == ray._private.worker.LOCAL_MODE:
#     374     assert (
#     375         not self._is_cross_language
#     376     ), "Cross language remote function cannot be executed locally."
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/signature.py:114, in flatten_args(signature_parameters, args, kwargs)
#     112     reconstructed_signature.bind(*args, **kwargs)
#     113 except TypeError as exc:  # capture a friendlier stacktrace
# --> 114     raise TypeError(str(exc)) from None
#     115 list_args = []
#     116 for arg in args:
#
# TypeError: missing a required argument: 'end_idx'

# %%
ray.get(futures)
# Out:
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102077.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102077.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1024771.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1024771.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026731.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026731.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1020611.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1020611.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102897.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102897.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1021666.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1021666.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103554.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103554.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102223.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102223.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101270.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101270.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025776.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025776.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103203.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103203.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1030211.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1030211.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1017621.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1017621.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100685.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100685.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100980.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100980.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100755.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100755.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026736.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026736.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100756.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100756.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/10216.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/10216.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1015936.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1015936.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101048.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101048.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100945.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100945.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101416.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101416.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101647.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101647.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1029531.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1029531.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100793.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100793.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101083.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101083.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1000256.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1000256.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1015136.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1015136.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025836.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025836.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031431.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031431.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031006.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031006.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1017346.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1017346.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025061.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025061.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028986.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028986.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028286.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028286.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1021426.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1021426.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1035046.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1035046.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103475.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103475.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1027506.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1027506.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101971.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101971.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1021686.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1021686.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102119.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102119.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1020306.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1020306.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1020141.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1020141.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100632.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100632.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026131.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026131.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101484.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101484.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100236.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100236.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1032146.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1032146.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102678.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102678.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026766.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026766.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101226.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101226.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1033791.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1033791.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1033621.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1033621.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1035726.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1035726.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031851.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031851.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100978.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100978.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101705.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101705.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1019.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1019.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1035236.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1035236.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026871.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026871.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103221.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103221.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1023531.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1023531.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101077.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101077.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026756.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026756.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1030126.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1030126.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026396.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026396.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1027216.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1027216.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100440.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100440.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1018126.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1018126.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100527.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100527.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101730.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101730.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1004766.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1004766.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103519.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103519.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1034256.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1034256.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025621.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025621.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101260.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101260.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1019841.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1019841.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1034431.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1034431.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1014411.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1014411.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016811.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016811.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102725.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102725.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1029141.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1029141.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016436.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016436.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100315.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100315.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026466.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026466.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100455.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100455.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031061.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031061.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016021.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016021.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1024246.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1024246.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102841.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102841.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025631.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025631.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102302.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102302.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025081.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025081.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101624.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101624.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100418.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100418.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1013106.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1013106.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102315.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102315.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1034706.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1034706.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1023196.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1023196.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1020861.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1020861.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1019866.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1019866.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100164.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100164.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1029636.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1029636.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1033906.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1033906.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025781.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025781.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102990.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102990.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101305.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101305.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100074.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100074.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028841.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028841.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1022036.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1022036.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100467.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100467.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103102.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103102.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100461.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100461.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1034336.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1034336.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1025506.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1025506.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016836.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016836.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016621.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016621.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101122.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101122.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1019026.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1019026.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102540.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102540.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1033011.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1033011.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1022746.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1022746.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103129.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103129.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1013111.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1013111.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100796.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100796.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031776.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031776.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100909.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100909.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1013291.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1013291.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028001.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028001.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632)
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1027526.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1027526.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/10311.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/10311.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1015456.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1015456.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100259.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100259.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1021286.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1021286.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028881.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028881.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102851.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102851.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103094.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103094.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100027.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100027.mscx...
# (process_chunk pid=8635) Exit code: -6
# (process_chunk pid=8635) Result:
# (process_chunk pid=8635) Errors:
# (process_chunk pid=8635) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1024581.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1024581.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101000.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101000.mscx...
# (process_chunk pid=8634) Exit code: -6
# (process_chunk pid=8634) Result:
# (process_chunk pid=8634) Errors:
# (process_chunk pid=8634) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100854.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100854.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1023721.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1023721.mscx...
# ...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016726.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016726.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100462.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100462.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100101.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100101.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100073.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100073.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100423.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100423.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101168.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101168.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1032371.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1032371.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1024371.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1024371.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102324.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102324.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1016411.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1016411.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102230.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102230.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1018476.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1018476.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101551.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101551.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100806.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100806.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031036.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031036.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103522.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103522.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031496.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031496.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102669.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102669.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1023996.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1023996.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028526.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028526.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/102215.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/102215.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1032936.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1032936.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1018581.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1018581.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101220.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101220.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031176.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031176.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1015621.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1015621.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/100032.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/100032.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103252.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103252.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101667.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101667.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1011.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1011.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101374.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101374.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103263.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103263.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101595.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101595.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1029896.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1029896.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101656.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101656.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1028056.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1028056.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1026.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1026.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1000866.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1000866.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1035251.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1035251.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103485.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103485.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1023351.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1023351.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1031066.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1031066.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101859.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101859.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/101155.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/101155.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8632) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1023571.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1023571.mscx...
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/103144.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/103144.mscx...
# (process_chunk pid=8632) Exit code: -6
# (process_chunk pid=8632) Result:
# (process_chunk pid=8632) Errors:
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:
# (process_chunk pid=8633) Converting /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscz/1029411.mscz to /home/nathan/Documents/Cours/EPFL_ML_CS433/ComposersClassifier/ml_project/mscx/1029411.mscx...
# [None, None, None, None, None, None, None, None, None, None]
# (process_chunk pid=8633) Exit code: -6
# (process_chunk pid=8633) Result:
# (process_chunk pid=8633) Errors:

# %%
# for i, entry in enumerate(os.scandir(SAMPLE_FOLDER)):
#     if i == 10:
#         break
#     ID, file_extension = os.path.splitext(entry.name)
#     converted_file_path = os.path.join(CONVERSION_FOLDER, ID + '.mscx')
#     print(f"Converting {entry.path} to {converted_file_path}...", end=' ')
    
#     result = subprocess.run([musescore_cmd,"--score-meta", "-o", converted_file_path, entry.path], capture_output=True, text=True)
#     print(f"Exit code: {result.returncode}")
#     print(f"Result: {result.stdout.strip()}") # the extraction of metadata as JSON does not work on Windows; please store the JSON to the metadata output folder
#     print(f"Errors: {result.stderr.strip()}")
# Out:
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/100462.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/100462.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Erin Taylor Nicole"]},"timesig":"4/4","title":"Erin Taylor Nicole"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020611.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020611.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"Arr. Raven Simon","duration":79,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":-1,"lyrics":"","measures":48,"mscoreVersion":"2.0.0","pageFormat":{"height":279,"twosided":"false","width":216},"pages":7,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"Flute","program":73},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"Alto Saxophone","program":65},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.clarinet.bass","isVisible":"true","lyricCount":0,"name":"Bass Clarinet","program":71},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"Baritone Saxophone","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.bflat","isVisible":"true","lyricCount":0,"name":"B♭ Trumpet","program":56},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.french-horn","isVisible":"true","lyricCount":0,"name":"Horn in F","program":60},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.tuba","isVisible":"true","lyricCount":0,"name":"Tuba","program":58},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.marimba","isVisible":"true","lyricCount":0,"name":"Marimba","program":12},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.vibraphone","isVisible":"true","lyricCount":0,"name":"Vibraphone","program":11},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pitched-percussion.xylophone","isVisible":"true","lyricCount":0,"name":"Xylophone","program":13},{"harmonyCount":0,"hasDrumStaff":"fal ...
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1035766.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1035766.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"","duration":16,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":8,"mscoreVersion":"1.2","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["#9 Bass Cleff song #3"]},"timesig":"4/4","title":"#9 Bass Cleff song #3"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1014811.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1014811.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"JAVIER BARANDIARAN URIARTE","duration":28,"fileVersion":206,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":14,"mscoreVersion":"2.0.1","pageFormat":{"height":297,"twosided":"true","width":210},"pages":1,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trumpet.c","isVisible":"true","lyricCount":0,"name":"Trompeta en Do","program":56},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"Set de percusión","program":0},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"metal.cymbal.crash","isVisible":"true","lyricCount":0,"name":"Platillos","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":0,"tempoText":"","textFramesData":{"composers":["JAVIER BARANDIARAN URIARTE"],"poets":[],"subtitles":[],"titles":["TOQUE MILITAR"]},"timesig":"4/4","title":"TOQUE MILITAR"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013421.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1013421.mscx... Exit code: 1
# Result:
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# QZip: not a zip file!
# Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1013421.mscz:
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102669.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102669.mscx... Exit code: 1
# Result:
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# QZip: not a zip file!
# Cannot read file /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102669.mscz:
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1020831.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1020831.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"","duration":109,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"true","keysig":-3,"lyrics":"Ohthere's no place like home. 'Midpleasuressures and palaces throughwe may roam. Be it ever so humble there's noplace like home. A charmfrom the skies seems to hallow us there, which seekthrough the world is not metwith elsewhere. Oh there's noplace like home, Oh there's noplace like home, \n\nOhthere's no place likehome. Be it ever so humble there's noplace like home. A charmfrom the skies seems to hallow us there, which seek through the world is not met with elsewhere. Oh there's no place like home, Oh there's no place like home. \n\nA charmfrom the skies seems to hallow us there, which seekthrough the world is not metwith elsewhere. Home, home sweet home, Oh there's no place like home. Oh there's no place like home. \n\nHome, home sweet home, Oh there'sno place like home. Oh there's no place like home. \n\nWhich seekthrough the worldis not metwith elsewhere. Homehome sweet home, Oh there's no place like home. Oh there's noplace like home. \n\nHome, home sweet home, Ohthere's no place like home. Oh there's noplace like home.","measures":91,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":5,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.soprano","isVisible":"true","lyricCount":63,"name":"<font face=\"Times New Roman\"/>Soprano","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.soprano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Soprano","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.alto","isVisible":"true","lyricCount":52,"name":"<font face=\"Times New Roman\"/>Alto","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.alto","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Alto","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.tenor","isVisible":"true","lyricCount":38,"name":"<font face=\"Times New Roman\"/>Tenor","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.tenor","isVisible":"true","lyricCount":16,"name":"<font face=\"Times New Roman\"/>Tenor","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.bass","isVisible":"true","lyricCount":27,"name":"<font face=\"Times New Roman\"/>Bass","program":67},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"voice.bass","isVisible":"true","lyricCount":16,"name":"<font face=\"Times New Roman\"/>Bass","program":67}],"poet":"","previousSource":"","subtitle":"","tempo":160,"tempoText":"<font face=\"Times New Roman\"/><b>Presto</b>","textFramesData":{"composers":[],"poets":[],"subtitles":[],"titles":["Home"]},"timesig":"4/4","title":"Home"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/1031601.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/1031601.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"Lucy Berman","duration":53,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":4,"lyrics":"","measures":32,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":2,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Piano","program":0}],"poet":"Seal","previousSource":"","subtitle":"Triple Trio","tempo":144,"tempoText":"<font face=\"Times New Roman\"/><b>Vivace</b>","textFramesData":{"composers":["Lucy Berman"],"poets":["Seal"],"subtitles":["Triple Trio"],"titles":["Kiss From a Rose"]},"timesig":"4/4","title":"Kiss From a Rose"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/101210.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/101210.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"Gabriel Joseph Manning Welsh","duration":144,"fileVersion":114,"hasHarmonies":"false","hasLyrics":"false","keysig":0,"lyrics":"","measures":44,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":4,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.violin","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violin","program":40},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"strings.cello","isVisible":"true","lyricCount":0,"name":"<font face=\"Times New Roman\"/>Violoncello","program":42}],"poet":"","previousSource":"","subtitle":"A new found life","tempo":0,"tempoText":"","textFramesData":{"composers":["Gabriel Joseph Manning Welsh"],"poets":[],"subtitles":["A new found life"],"titles":[]},"timesig":"4/4","title":"101210"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# Converting /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscz/102971.mscz to /home/erwan/epfl/s1/ml/ComposersClassifier/data/mscx/102971.mscx... Exit code: 0
# Result: {
# "metadata": {"composer":"by Nina Simone\narr. Romain P.","duration":191,"fileVersion":114,"hasHarmonies":"true","hasLyrics":"false","keysig":0,"lyrics":"","measures":69,"mscoreVersion":"1.3","pageFormat":{"height":297,"twosided":"true","width":210},"pages":34,"parts":[{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.flutes.flute","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Flute","program":73},{"harmonyCount":11,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.alto","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Alto Saxophone","program":65},{"harmonyCount":4,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.tenor","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Tenor Saxophone","program":66},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"wind.reed.saxophone.baritone","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Baritone Saxophone","program":67},{"harmonyCount":5,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.cornet.soprano","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>B<font size=\"14.8538\"/><font face=\"MScore1\"/><sym>accidentalFlat</sym><font size=\"12.3782\"/><font face=\"Times New Roman\"/> Trumpet","program":56},{"harmonyCount":2,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Trombone","program":57},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"brass.trombone.bass","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Bass Trombone","program":57},{"harmonyCount":35,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.guitar.electric","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Electric Guitar","program":27},{"harmonyCount":0,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"pluck.bass.electric","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Electric Bass","program":33},{"harmonyCount":45,"hasDrumStaff":"false","hasPitchedStaff":"true","hasTabStaff":"false","instrumentId":"keyboard.piano","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Piano","program":0},{"harmonyCount":0,"hasDrumStaff":"true","hasPitchedStaff":"false","hasTabStaff":"false","instrumentId":"drum.group.set","isVisible":"true","lyricCount":0,"name":"<font size=\"12.3782\"/><font face=\"Times New Roman\"/>Drumset","program":0}],"poet":"","previousSource":"","subtitle":"","tempo":132,"tempoText":"<sym>metNoteQuarterUp</sym> = 132","textFramesData":{"composers":["by Nina Simone\narr. Romain P."],"poets":[],"subtitles":[],"titles":["Feeling Good"]},"timesig":"12/8","title":"Feeling Good"}
# }
# Errors: /lib/x86_64-linux-gnu/libjack.so.0
# /lib/x86_64-linux-gnu/libnss3.so
# Creating main window…
# Reading translations…
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known
# text style <12> not known

# %% [markdown]
# Using the ms3 parsing library to extract score information:

# %%
for entry in os.scandir(CONVERSION_FOLDER):
    if entry.is_dir():
        continue
    parsed = ms3.Score(entry.path, read_only=True)
    ID, _ = os.path.splitext(entry.name)
    tsv_name = f"{ID}.tsv"
    dataframes = dict(
        events = parsed.mscx.events(),
        notes = parsed.mscx.notes(),
        measures = parsed.mscx.measures(),
        labels = parsed.mscx.labels(),
    )
    for facet, df in dataframes.items():
        if df is None:
            continue
        tsv_path = os.path.join(OUTPUT_PATHS[facet], tsv_name)
        df.to_csv(tsv_path, sep='\t', index=False)
    metadata = parsed.mscx.metadata # please add this nested dictionary to the JSON stored in the previous step
    metadata['id'] = ID
# Out:
# INCORRECT_VOLTA_MN_WARNING (2, 15) ms3.Score.100027.mscx -- c:\users\hentsche\pycharmprojects\ms3\src\ms3\bs4_measures.py (line 184) check_measure_numbers():
# 	MC 15, the 1st measure of a 2nd volta, should have MN 14, not MN 15.
